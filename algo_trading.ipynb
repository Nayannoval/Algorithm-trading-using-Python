# %%
! pip install yfinance

# %%
import yfinance as yf

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Apple = yf.download("AAPL", start = "2010-01-01", end ="2024-05-31" )
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
Apple
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-01-04    7.622500    7.660714    7.585000    7.643214    6.470742
# 2010-01-05    7.664286    7.699643    7.616071    7.656429    6.481929
# 2010-01-06    7.656429    7.686786    7.526786    7.534643    6.378825
# 2010-01-07    7.562500    7.571429    7.466071    7.520714    6.367032
# 2010-01-08    7.510714    7.571429    7.466429    7.570714    6.409362
# ...                ...         ...         ...         ...         ...
# 2024-05-23  190.979996  191.000000  186.630005  186.880005  186.880005
# 2024-05-24  188.820007  190.580002  188.039993  189.979996  189.979996
# 2024-05-28  191.509995  193.000000  189.100006  189.990005  189.990005
# 2024-05-29  189.610001  192.250000  189.509995  190.289993  190.289993
# 2024-05-30  190.759995  192.179993  190.630005  191.289993  191.289993
#
#                Volume
# Date
# 2010-01-04  493729600
# 2010-01-05  601904800
# 2010-01-06  552160000
# ...

# %%
ticker = ["SPY","AAPL","KO","JPM","IBM"]

# %%
stocks = yf.download(ticker, start = "2010-01-01", end ="2024-05-31" )
# Out:
# [*********************100%%**********************]  5 of 5 completed

# %%
stocks
# Out:
# Price        Adj Close                                                 \
# Ticker            AAPL         IBM         JPM         KO         SPY
# Date
# 2010-01-04    6.470742   76.767426   29.497784  18.209930   86.860069
# 2010-01-05    6.481929   75.840073   30.069153  17.989655   87.089989
# 2010-01-06    6.378825   75.347404   30.234360  17.983267   87.151306
# 2010-01-07    6.367032   75.086601   30.833269  17.938568   87.519196
# 2010-01-08    6.409362   75.840073   30.757557  17.606554   87.810448
# ...                ...         ...         ...        ...         ...
# 2024-05-23  186.880005  170.669998  196.919998  61.611931  525.960022
# 2024-05-24  189.979996  170.889999  200.710007  61.522625  529.440002
# 2024-05-28  189.990005  169.660004  199.500000  61.344009  529.809998
# 2024-05-29  190.289993  167.050003  198.110001  61.224934  526.099976
# 2024-05-30  191.289993  165.630005  199.330002  61.492855  522.609985
#
# ...

# %%
stocks.tail()
# Out:
# Price        Adj Close                                                 \
# Ticker            AAPL         IBM         JPM         KO         SPY
# Date
# 2024-05-23  186.880005  170.669998  196.919998  61.611931  525.960022
# 2024-05-24  189.979996  170.889999  200.710007  61.522625  529.440002
# 2024-05-28  189.990005  169.660004  199.500000  61.344009  529.809998
# 2024-05-29  190.289993  167.050003  198.110001  61.224934  526.099976
# 2024-05-30  191.289993  165.630005  199.330002  61.492855  522.609985
#
# Price            Close                                                 ...  \
# Ticker            AAPL         IBM         JPM         KO         SPY  ...
# Date                                                                   ...
# 2024-05-23  186.880005  170.669998  196.919998  62.090000  525.960022  ...
# 2024-05-24  189.979996  170.889999  200.710007  62.000000  529.440002  ...
# 2024-05-28  189.990005  169.660004  199.500000  61.820000  529.809998  ...
# ...

# %%
stocks.to_csv("stocksYT.csv")

# %%
stocks = pd.read_csv("stocksYT.csv")

# %%
stocks
# Out:
#            Price           Adj Close         Adj Close.1         Adj Close.2  \
# 0         Ticker                AAPL                 IBM                 JPM
# 1           Date                 NaN                 NaN                 NaN
# 2     2010-01-04  6.4707417488098145   76.76742553710938  29.497783660888672
# 3     2010-01-05   6.481929302215576   75.84007263183594   30.06915283203125
# 4     2010-01-06  6.3788251876831055   75.34740447998047  30.234359741210938
# ...          ...                 ...                 ...                 ...
# 3623  2024-05-23   186.8800048828125   170.6699981689453   196.9199981689453
# 3624  2024-05-24  189.97999572753906  170.88999938964844   200.7100067138672
# 3625  2024-05-28  189.99000549316406  169.66000366210938               199.5
# 3626  2024-05-29   190.2899932861328   167.0500030517578  198.11000061035156
# 3627  2024-05-30   191.2899932861328   165.6300048828125   199.3300018310547
#
# ...

# %%
stocks = pd.read_csv("stocksYT.csv", header =[0,1],index_col=[0])
stocks
# Out:
# Price        Adj Close                                                 \
# Ticker            AAPL         IBM         JPM         KO         SPY
# Date
# 2010-01-04    6.470742   76.767426   29.497784  18.209930   86.860069
# 2010-01-05    6.481929   75.840073   30.069153  17.989655   87.089989
# 2010-01-06    6.378825   75.347404   30.234360  17.983267   87.151306
# 2010-01-07    6.367032   75.086601   30.833269  17.938568   87.519196
# 2010-01-08    6.409362   75.840073   30.757557  17.606554   87.810448
# ...                ...         ...         ...        ...         ...
# 2024-05-23  186.880005  170.669998  196.919998  61.611931  525.960022
# 2024-05-24  189.979996  170.889999  200.710007  61.522625  529.440002
# 2024-05-28  189.990005  169.660004  199.500000  61.344009  529.809998
# 2024-05-29  190.289993  167.050003  198.110001  61.224934  526.099976
# 2024-05-30  191.289993  165.630005  199.330002  61.492855  522.609985
#
# ...

# %%
stocks = pd.read_csv("stocksYT.csv", header =[0,1],index_col=[0],parse_dates=[0])
stocks
# Out:
# Price        Adj Close                                                 \
# Ticker            AAPL         IBM         JPM         KO         SPY
# Date
# 2010-01-04    6.470742   76.767426   29.497784  18.209930   86.860069
# 2010-01-05    6.481929   75.840073   30.069153  17.989655   87.089989
# 2010-01-06    6.378825   75.347404   30.234360  17.983267   87.151306
# 2010-01-07    6.367032   75.086601   30.833269  17.938568   87.519196
# 2010-01-08    6.409362   75.840073   30.757557  17.606554   87.810448
# ...                ...         ...         ...        ...         ...
# 2024-05-23  186.880005  170.669998  196.919998  61.611931  525.960022
# 2024-05-24  189.979996  170.889999  200.710007  61.522625  529.440002
# 2024-05-28  189.990005  169.660004  199.500000  61.344009  529.809998
# 2024-05-29  190.289993  167.050003  198.110001  61.224934  526.099976
# 2024-05-30  191.289993  165.630005  199.330002  61.492855  522.609985
#
# ...

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',  'IBM'),
#             ('Adj Close',  'JPM'),
#             ('Adj Close',   'KO'),
#             ('Adj Close',  'SPY'),
#             (    'Close', 'AAPL'),
#             (    'Close',  'IBM'),
#             (    'Close',  'JPM'),
#             (    'Close',   'KO'),
#             (    'Close',  'SPY'),
#             (     'High', 'AAPL'),
#             (     'High',  'IBM'),
#             (     'High',  'JPM'),
#             (     'High',   'KO'),
#             (     'High',  'SPY'),
#             (      'Low', 'AAPL'),
#             (      'Low',  'IBM'),
#             (      'Low',  'JPM'),
#             (      'Low',   'KO'),
#             (      'Low',  'SPY'),
#             (     'Open', 'AAPL'),
#             (     'Open',  'IBM'),
#             (     'Open',  'JPM'),
#             (     'Open',   'KO'),
#             (     'Open',  'SPY'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',  'IBM'),
# ...

# %%
stocks.columns = stocks.columns.to_flat_index()

# %%
stocks.columns
# Out:
# Index([('Adj Close', 'AAPL'),  ('Adj Close', 'IBM'),  ('Adj Close', 'JPM'),
#          ('Adj Close', 'KO'),  ('Adj Close', 'SPY'),     ('Close', 'AAPL'),
#             ('Close', 'IBM'),      ('Close', 'JPM'),       ('Close', 'KO'),
#             ('Close', 'SPY'),      ('High', 'AAPL'),       ('High', 'IBM'),
#              ('High', 'JPM'),        ('High', 'KO'),       ('High', 'SPY'),
#              ('Low', 'AAPL'),        ('Low', 'IBM'),        ('Low', 'JPM'),
#                ('Low', 'KO'),        ('Low', 'SPY'),      ('Open', 'AAPL'),
#              ('Open', 'IBM'),       ('Open', 'JPM'),        ('Open', 'KO'),
#              ('Open', 'SPY'),    ('Volume', 'AAPL'),     ('Volume', 'IBM'),
#            ('Volume', 'JPM'),      ('Volume', 'KO'),     ('Volume', 'SPY')],
#       dtype='object')

# %%
stocks
# Out:
#             (Adj Close, AAPL)  (Adj Close, IBM)  (Adj Close, JPM)  \
# Date
# 2010-01-04           6.470742         76.767426         29.497784
# 2010-01-05           6.481929         75.840073         30.069153
# 2010-01-06           6.378825         75.347404         30.234360
# 2010-01-07           6.367032         75.086601         30.833269
# 2010-01-08           6.409362         75.840073         30.757557
# ...                       ...               ...               ...
# 2024-05-23         186.880005        170.669998        196.919998
# 2024-05-24         189.979996        170.889999        200.710007
# 2024-05-28         189.990005        169.660004        199.500000
# 2024-05-29         190.289993        167.050003        198.110001
# 2024-05-30         191.289993        165.630005        199.330002
#
#             (Adj Close, KO)  (Adj Close, SPY)  (Close, AAPL)  (Close, IBM)  \
# Date
# 2010-01-04        18.209930         86.860069       7.643214    126.625237
# ...

# %%
stocks.describe()
# Out:
#        (Adj Close, AAPL)  (Adj Close, IBM)  (Adj Close, JPM)  (Adj Close, KO)  \
# count        3626.000000       3626.000000       3626.000000      3626.000000
# mean           61.350811        110.839892         77.238320        37.356620
# std            58.655045         19.161109         44.360685        12.569538
# min             5.806766         70.936714         20.035664        16.118814
# 25%            17.247019        100.916355         39.327417        27.930517
# 50%            32.724741        109.109161         70.862617        34.791456
# 75%           115.078369        119.770151        109.187201        46.966022
# max           197.857529        197.779999        204.789993        63.090462
#
#        (Adj Close, SPY)  (Close, AAPL)  (Close, IBM)  (Close, JPM)  \
# count       3626.000000    3626.000000   3626.000000   3626.000000
# mean         238.113959      63.372631    148.719119     89.221969
# ...

# %%
stocks.columns
# Out:
# Index([('Adj Close', 'AAPL'),  ('Adj Close', 'IBM'),  ('Adj Close', 'JPM'),
#          ('Adj Close', 'KO'),  ('Adj Close', 'SPY'),     ('Close', 'AAPL'),
#             ('Close', 'IBM'),      ('Close', 'JPM'),       ('Close', 'KO'),
#             ('Close', 'SPY'),      ('High', 'AAPL'),       ('High', 'IBM'),
#              ('High', 'JPM'),        ('High', 'KO'),       ('High', 'SPY'),
#              ('Low', 'AAPL'),        ('Low', 'IBM'),        ('Low', 'JPM'),
#                ('Low', 'KO'),        ('Low', 'SPY'),      ('Open', 'AAPL'),
#              ('Open', 'IBM'),       ('Open', 'JPM'),        ('Open', 'KO'),
#              ('Open', 'SPY'),    ('Volume', 'AAPL'),     ('Volume', 'IBM'),
#            ('Volume', 'JPM'),      ('Volume', 'KO'),     ('Volume', 'SPY')],
#       dtype='object')

# %%
close=stocks.loc[:,[('Close', 'IBM'),  ('Close', 'JPM'),  ('Close', 'KO'), ('Close', 'SPY')]].copy()

# %%
close
# Out:
#             (Close, IBM)  (Close, JPM)  (Close, KO)  (Close, SPY)
# Date
# 2010-01-04    126.625237     42.849998    28.520000    113.330002
# 2010-01-05    125.095604     43.680000    28.174999    113.629997
# 2010-01-06    124.282982     43.919998    28.165001    113.709999
# 2010-01-07    123.852776     44.790001    28.094999    114.190002
# 2010-01-08    125.095604     44.680000    27.575001    114.570000
# ...                  ...           ...          ...           ...
# 2024-05-23    170.669998    196.919998    62.090000    525.960022
# 2024-05-24    170.889999    200.710007    62.000000    529.440002
# 2024-05-28    169.660004    199.500000    61.820000    529.809998
# 2024-05-29    167.050003    198.110001    61.700001    526.099976
# 2024-05-30    165.630005    199.330002    61.970001    522.609985
#
# [3626 rows x 4 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
# plt.style.use("seaborn")

# %%
 close.plot(figsize = (15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %% [markdown]
# SPY went the most up. Cocacola has most normal growth with less volatility.

# %%
close.iloc[0,0]
# Out:
# 126.62523651123048

# %%
close_ibm=close[[('Close', 'IBM')]]

# %%
close_ibm.div(close.iloc[0,0])
# Out:
#             (Close, IBM)
# Date
# 2010-01-04      1.000000
# 2010-01-05      0.987920
# 2010-01-06      0.981502
# 2010-01-07      0.978105
# 2010-01-08      0.987920
# ...                  ...
# 2024-05-23      1.347836
# 2024-05-24      1.349573
# 2024-05-28      1.339859
# 2024-05-29      1.319247
# 2024-05-30      1.308033
#
# [3626 rows x 1 columns]

# %%
close_ibm.div(close.iloc[0,0]).mul(100)
# Out:
#             (Close, IBM)
# Date
# 2010-01-04    100.000000
# 2010-01-05     98.792000
# 2010-01-06     98.150247
# 2010-01-07     97.810499
# 2010-01-08     98.792000
# ...                  ...
# 2024-05-23    134.783557
# 2024-05-24    134.957299
# 2024-05-28    133.985932
# 2024-05-29    131.924731
# 2024-05-30    130.803313
#
# [3626 rows x 1 columns]

# %%
close_jpm=close.iloc[:,2]

# %%
close_jpm.div(close.iloc[0,2]).mul(100)
# Out:
# Date
# 2010-01-04    100.000000
# 2010-01-05     98.790318
# 2010-01-06     98.755261
# 2010-01-07     98.509814
# 2010-01-08     96.686537
#                  ...
# 2024-05-23    217.706869
# 2024-05-24    217.391301
# 2024-05-28    216.760164
# 2024-05-29    216.339410
# 2024-05-30    217.286116
# Name: (Close, KO), Length: 3626, dtype: float64

# %%
close_jpm
# Out:
# Date
# 2010-01-04    28.520000
# 2010-01-05    28.174999
# 2010-01-06    28.165001
# 2010-01-07    28.094999
# 2010-01-08    27.575001
#                 ...
# 2024-05-23    62.090000
# 2024-05-24    62.000000
# 2024-05-28    61.820000
# 2024-05-29    61.700001
# 2024-05-30    61.970001
# Name: (Close, KO), Length: 3626, dtype: float64

# %%
close.div(close.iloc[0]).mul(100)
# Out:
#             (Close, IBM)  (Close, JPM)  (Close, KO)  (Close, SPY)
# Date
# 2010-01-04    100.000000    100.000000   100.000000    100.000000
# 2010-01-05     98.792000    101.936994    98.790318    100.264710
# 2010-01-06     98.150247    102.497082    98.755261    100.335302
# 2010-01-07     97.810499    104.527427    98.509814    100.758846
# 2010-01-08     98.792000    104.270716    96.686537    101.094148
# ...                  ...           ...          ...           ...
# 2024-05-23    134.783557    459.556605   217.706869    464.096015
# 2024-05-24    134.957299    468.401433   217.391301    467.166676
# 2024-05-28    133.985932    465.577613   216.760164    467.493152
# 2024-05-29    131.924731    462.333740   216.339410    464.219507
# 2024-05-30    130.803313    465.180884   217.286116    461.140013
#
# [3626 rows x 4 columns]

# %%
normclose=close.div(close.iloc[0]).mul(100)

# %%
 normclose.plot(figsize = (15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
close.columns
# Out:
# Index([('Close', 'IBM'), ('Close', 'JPM'), ('Close', 'KO'), ('Close', 'SPY')], dtype='object')

# %%
jpm = close[('Close', 'JPM')].copy().to_frame()

# %%
jpm
# Out:
#                  Close
#                    JPM
# Date
# 2010-01-04   42.849998
# 2010-01-05   43.680000
# 2010-01-06   43.919998
# 2010-01-07   44.790001
# 2010-01-08   44.680000
# ...                ...
# 2024-05-23  196.919998
# 2024-05-24  200.710007
# 2024-05-28  199.500000
# 2024-05-29  198.110001
# 2024-05-30  199.330002
#
# [3626 rows x 1 columns]

# %%
jpm.shift(periods=1)
# Out:
#                  Close
#                    JPM
# Date
# 2010-01-04         NaN
# 2010-01-05   42.849998
# 2010-01-06   43.680000
# 2010-01-07   43.919998
# 2010-01-08   44.790001
# ...                ...
# 2024-05-23  198.309998
# 2024-05-24  196.919998
# 2024-05-28  200.710007
# 2024-05-29  199.500000
# 2024-05-30  198.110001
#
# [3626 rows x 1 columns]

# %%
jpm["lag1"]=jpm.shift(periods=1)

# %%
jpm
# Out:
#                  Close        lag1
#                    JPM
# Date
# 2010-01-04   42.849998         NaN
# 2010-01-05   43.680000   42.849998
# 2010-01-06   43.919998   43.680000
# 2010-01-07   44.790001   43.919998
# 2010-01-08   44.680000   44.790001
# ...                ...         ...
# 2024-05-23  196.919998  198.309998
# 2024-05-24  200.710007  196.919998
# 2024-05-28  199.500000  200.710007
# 2024-05-29  198.110001  199.500000
# 2024-05-30  199.330002  198.110001
#
# [3626 rows x 2 columns]

# %%
jpm.columns
# Out:
# MultiIndex([('Close', 'JPM'),
#             ( 'lag1',    '')],
#            )

# %%
jpm['diff']=jpm[('Close', 'JPM')].sub(jpm['lag1'])

# %%
jpm
# Out:
#                  Close        lag1      diff
#                    JPM
# Date
# 2010-01-04   42.849998         NaN       NaN
# 2010-01-05   43.680000   42.849998  0.830002
# 2010-01-06   43.919998   43.680000  0.239998
# 2010-01-07   44.790001   43.919998  0.870003
# 2010-01-08   44.680000   44.790001 -0.110001
# ...                ...         ...       ...
# 2024-05-23  196.919998  198.309998 -1.389999
# 2024-05-24  200.710007  196.919998  3.790009
# 2024-05-28  199.500000  200.710007 -1.210007
# 2024-05-29  198.110001  199.500000 -1.389999
# 2024-05-30  199.330002  198.110001  1.220001
#
# [3626 rows x 3 columns]

# %%
jpm['%change']=jpm[('Close', 'JPM')].div(jpm['lag1']).sub(1).mul(100)

# %%
jpm
# Out:
#                  Close        lag1      diff   %change
#                    JPM
# Date
# 2010-01-04   42.849998         NaN       NaN       NaN
# 2010-01-05   43.680000   42.849998  0.830002  1.936994
# 2010-01-06   43.919998   43.680000  0.239998  0.549446
# 2010-01-07   44.790001   43.919998  0.870003  1.980881
# 2010-01-08   44.680000   44.790001 -0.110001 -0.245592
# ...                ...         ...       ...       ...
# 2024-05-23  196.919998  198.309998 -1.389999 -0.700922
# 2024-05-24  200.710007  196.919998  3.790009  1.924644
# 2024-05-28  199.500000  200.710007 -1.210007 -0.602863
# 2024-05-29  198.110001  199.500000 -1.389999 -0.696742
# 2024-05-30  199.330002  198.110001  1.220001  0.615820
#
# [3626 rows x 4 columns]

# %%
jpm['diff2']=jpm[('Close', 'JPM')].diff(periods=1)
jpm
# Out:
#                  Close        lag1      diff   %change     diff2
#                    JPM
# Date
# 2010-01-04   42.849998         NaN       NaN       NaN       NaN
# 2010-01-05   43.680000   42.849998  0.830002  1.936994  0.830002
# 2010-01-06   43.919998   43.680000  0.239998  0.549446  0.239998
# 2010-01-07   44.790001   43.919998  0.870003  1.980881  0.870003
# 2010-01-08   44.680000   44.790001 -0.110001 -0.245592 -0.110001
# ...                ...         ...       ...       ...       ...
# 2024-05-23  196.919998  198.309998 -1.389999 -0.700922 -1.389999
# 2024-05-24  200.710007  196.919998  3.790009  1.924644  3.790009
# 2024-05-28  199.500000  200.710007 -1.210007 -0.602863 -1.210007
# 2024-05-29  198.110001  199.500000 -1.389999 -0.696742 -1.389999
# 2024-05-30  199.330002  198.110001  1.220001  0.615820  1.220001
#
# [3626 rows x 5 columns]

# %%
jpm['%change2']=jpm[('Close', 'JPM')].pct_change(periods=1).mul(100)

# %%
jpm
# Out:
#                  Close        lag1      diff   %change     diff2  %change2
#                    JPM
# Date
# 2010-01-04   42.849998         NaN       NaN       NaN       NaN       NaN
# 2010-01-05   43.680000   42.849998  0.830002  1.936994  0.830002  1.936994
# 2010-01-06   43.919998   43.680000  0.239998  0.549446  0.239998  0.549446
# 2010-01-07   44.790001   43.919998  0.870003  1.980881  0.870003  1.980881
# 2010-01-08   44.680000   44.790001 -0.110001 -0.245592 -0.110001 -0.245592
# ...                ...         ...       ...       ...       ...       ...
# 2024-05-23  196.919998  198.309998 -1.389999 -0.700922 -1.389999 -0.700922
# 2024-05-24  200.710007  196.919998  3.790009  1.924644  3.790009  1.924644
# 2024-05-28  199.500000  200.710007 -1.210007 -0.602863 -1.210007 -0.602863
# 2024-05-29  198.110001  199.500000 -1.389999 -0.696742 -1.389999 -0.696742
# 2024-05-30  199.330002  198.110001  1.220001  0.615820  1.220001  0.615820
#
# [3626 rows x 6 columns]

# %%
del jpm['lag1']

# %%
jpm
# Out:
#                  Close      diff   %change     diff2  %change2
#                    JPM
# Date
# 2010-01-04   42.849998       NaN       NaN       NaN       NaN
# 2010-01-05   43.680000  0.830002  1.936994  0.830002  1.936994
# 2010-01-06   43.919998  0.239998  0.549446  0.239998  0.549446
# 2010-01-07   44.790001  0.870003  1.980881  0.870003  1.980881
# 2010-01-08   44.680000 -0.110001 -0.245592 -0.110001 -0.245592
# ...                ...       ...       ...       ...       ...
# 2024-05-23  196.919998 -1.389999 -0.700922 -1.389999 -0.700922
# 2024-05-24  200.710007  3.790009  1.924644  3.790009  1.924644
# 2024-05-28  199.500000 -1.210007 -0.602863 -1.210007 -0.602863
# 2024-05-29  198.110001 -1.389999 -0.696742 -1.389999 -0.696742
# 2024-05-30  199.330002  1.220001  0.615820  1.220001  0.615820
#
# [3626 rows x 5 columns]

# %%
jpm.columns
# Out:
# MultiIndex([(   'Close', 'JPM'),
#             (    'diff',    ''),
#             ( '%change',    ''),
#             (   'diff2',    ''),
#             ('%change2',    '')],
#            )

# %%
jpm.rename(columns={('Close'):'close'},inplace=True)

# %%
jpm
# Out:
#                  close      diff   %change     diff2  %change2
#                    JPM
# Date
# 2010-01-04   42.849998       NaN       NaN       NaN       NaN
# 2010-01-05   43.680000  0.830002  1.936994  0.830002  1.936994
# 2010-01-06   43.919998  0.239998  0.549446  0.239998  0.549446
# 2010-01-07   44.790001  0.870003  1.980881  0.870003  1.980881
# 2010-01-08   44.680000 -0.110001 -0.245592 -0.110001 -0.245592
# ...                ...       ...       ...       ...       ...
# 2024-05-23  196.919998 -1.389999 -0.700922 -1.389999 -0.700922
# 2024-05-24  200.710007  3.790009  1.924644  3.790009  1.924644
# 2024-05-28  199.500000 -1.210007 -0.602863 -1.210007 -0.602863
# 2024-05-29  198.110001 -1.389999 -0.696742 -1.389999 -0.696742
# 2024-05-30  199.330002  1.220001  0.615820  1.220001  0.615820
#
# [3626 rows x 5 columns]

# %%
jpm.columns
# Out:
# MultiIndex([(   'close', 'JPM'),
#             (    'diff',    ''),
#             ( '%change',    ''),
#             (   'diff2',    ''),
#             ('%change2',    '')],
#            )

# %%
jpm[( 'close', 'JPM')].resample('M').last()
# Out:
# Date
# 2010-01-31     38.939999
# 2010-02-28     41.970001
# 2010-03-31     44.750000
# 2010-04-30     42.580002
# 2010-05-31     39.580002
#                  ...
# 2024-01-31    174.360001
# 2024-02-29    186.059998
# 2024-03-31    200.300003
# 2024-04-30    191.740005
# 2024-05-31    199.330002
# Freq: M, Name: (close, JPM), Length: 173, dtype: float64

# %%
jpm[( 'close', 'JPM')].resample('BM').last().pct_change(periods=1).mul(100)
# Out:
# Date
# 2010-01-29         NaN
# 2010-02-26    7.781209
# 2010-03-31    6.623776
# 2010-04-30   -4.849158
# 2010-05-31   -7.045561
#                 ...
# 2024-01-31    2.504406
# 2024-02-29    6.710253
# 2024-03-29    7.653448
# 2024-04-30   -4.273588
# 2024-05-31    3.958483
# Freq: BM, Name: (close, JPM), Length: 173, dtype: float64

# %%
jpm.columns
# Out:
# MultiIndex([(   'close', 'JPM'),
#             (    'diff',    ''),
#             ( '%change',    ''),
#             (   'diff2',    ''),
#             ('%change2',    '')],
#            )

# %%
 del jpm['%change']

# %%
del jpm['diff']

# %%
del jpm['diff2']

# %%
jpm
# Out:
#                  close  %change2
#                    JPM
# Date
# 2010-01-04   42.849998       NaN
# 2010-01-05   43.680000  1.936994
# 2010-01-06   43.919998  0.549446
# 2010-01-07   44.790001  1.980881
# 2010-01-08   44.680000 -0.245592
# ...                ...       ...
# 2024-05-23  196.919998 -0.700922
# 2024-05-24  200.710007  1.924644
# 2024-05-28  199.500000 -0.602863
# 2024-05-29  198.110001 -0.696742
# 2024-05-30  199.330002  0.615820
#
# [3626 rows x 2 columns]

# %%
ticker=['SPY','AAPL','JPM','IBM','DIS','MSFT']

# %%
stocks=yf.download(ticker , start= "2010-01-01" ,end = "2024-05-31")
# Out:
# [*********************100%%**********************]  6 of 6 completed

# %%
stocks
# Out:
# Price        Adj Close                                                  \
# Ticker            AAPL         DIS         IBM         JPM        MSFT
# Date
# 2010-01-04    6.470742   27.843180   76.767426   29.497784   23.431595
# 2010-01-05    6.481929   27.773718   75.840073   30.069153   23.439159
# 2010-01-06    6.378825   27.626125   75.347404   30.234360   23.295315
# 2010-01-07    6.367032   27.634809   75.086601   30.833269   23.053049
# 2010-01-08    6.409362   27.678223   75.840073   30.757557   23.212034
# ...                ...         ...         ...         ...         ...
# 2024-05-23  186.880005  100.660004  170.669998  196.919998  427.000000
# 2024-05-24  189.979996  101.760002  170.889999  200.710007  430.160004
# 2024-05-28  189.990005  102.440002  169.660004  199.500000  430.320007
# 2024-05-29  190.289993  100.879997  167.050003  198.110001  429.170013
# 2024-05-30  191.289993  101.699997  165.630005  199.330002  414.670013
#
# ...

# %%
close=stocks.loc[:,"Close"].copy()
close
# Out:
# Ticker            AAPL         DIS         IBM         JPM        MSFT  \
# Date
# 2010-01-04    7.643214   32.070000  126.625237   42.849998   30.950001
# 2010-01-05    7.656429   31.990000  125.095604   43.680000   30.959999
# 2010-01-06    7.534643   31.820000  124.282982   43.919998   30.770000
# 2010-01-07    7.520714   31.830000  123.852776   44.790001   30.450001
# 2010-01-08    7.570714   31.879999  125.095604   44.680000   30.660000
# ...                ...         ...         ...         ...         ...
# 2024-05-23  186.880005  100.660004  170.669998  196.919998  427.000000
# 2024-05-24  189.979996  101.760002  170.889999  200.710007  430.160004
# 2024-05-28  189.990005  102.440002  169.660004  199.500000  430.320007
# 2024-05-29  190.289993  100.879997  167.050003  198.110001  429.170013
# 2024-05-30  191.289993  101.699997  165.630005  199.330002  414.670013
#
# Ticker             SPY
# Date
# 2010-01-04  113.330002
# 2010-01-05  113.629997
# 2010-01-06  113.709999
# ...

# %%
normclose=close.div(close.iloc[0]).mul(100)
normclose
# Out:
# Ticker             AAPL         DIS         IBM         JPM         MSFT  \
# Date
# 2010-01-04   100.000000  100.000000  100.000000  100.000000   100.000000
# 2010-01-05   100.172893   99.750546   98.792000  101.936994   100.032305
# 2010-01-06    98.579511   99.220455   98.150247  102.497082    99.418416
# 2010-01-07    98.397266   99.251638   97.810499  104.527427    98.384491
# 2010-01-08    99.051443   99.407544   98.792000  104.270716    99.063002
# ...                 ...         ...         ...         ...          ...
# 2024-05-23  2445.044707  313.875911  134.783557  459.556605  1379.644554
# 2024-05-24  2485.603440  317.305903  134.957299  468.401433  1389.854582
# 2024-05-28  2485.734403  319.426266  133.985932  465.577613  1390.371556
# 2024-05-29  2489.659293  314.561890  131.924731  462.333740  1386.655906
# 2024-05-30  2502.742794  317.118796  130.803313  465.180884  1339.806149
#
# Ticker             SPY
# Date
# 2010-01-04  100.000000
# 2010-01-05  100.264710
# ...

# %%
normclose.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
ret=close.pct_change().dropna()

# %%
ret.head()
# Out:
# Ticker          AAPL       DIS       IBM       JPM      MSFT       SPY
# Date
# 2010-01-05  0.001729 -0.002495 -0.012080  0.019370  0.000323  0.002647
# 2010-01-06 -0.015906 -0.005314 -0.006496  0.005494 -0.006137  0.000704
# 2010-01-07 -0.001849  0.000314 -0.003462  0.019809 -0.010400  0.004221
# 2010-01-08  0.006648  0.001571  0.010035 -0.002456  0.006897  0.003328
# 2010-01-11 -0.008821 -0.016311 -0.010470 -0.003357 -0.012720  0.001397

# %%
close.mean()
# Out:
# Ticker
# AAPL     63.372631
# DIS      95.067129
# IBM     148.719119
# JPM      89.221969
# MSFT    123.723610
# SPY     260.482449
# dtype: float64

# %%
close.std()
# Out:
# Ticker
# AAPL     58.226533
# DIS      38.710045
# IBM      23.775631
# JPM      42.571639
# MSFT    111.742136
# SPY     113.219135
# dtype: float64

# %%
np.sqrt(close.var())
# Out:
# Ticker
# AAPL     58.226533
# DIS      38.710045
# IBM      23.775631
# JPM      42.571639
# MSFT    111.742136
# SPY     113.219135
# dtype: float64

# %%
ret.describe().T
# Out:
#          count      mean       std       min       25%       50%       75%  \
# Ticker
# AAPL    3625.0  0.001045  0.017683 -0.128647 -0.007553  0.000865  0.010348
# DIS     3625.0  0.000455  0.016538 -0.131632 -0.006848  0.000433  0.008240
# IBM     3625.0  0.000174  0.014092 -0.128507 -0.006318  0.000394  0.006987
# JPM     3625.0  0.000578  0.017539 -0.149649 -0.007713  0.000431  0.009021
# MSFT    3625.0  0.000848  0.016253 -0.147390 -0.007191  0.000589  0.009205
# SPY     3625.0  0.000481  0.010865 -0.109424 -0.003836  0.000599  0.005779
#
#              max
# Ticker
# AAPL    0.119808
# DIS     0.144123
# IBM     0.113010
# JPM     0.180125
# MSFT    0.142169
# SPY     0.090603

# %%
summary=ret.describe().T.loc[:,['mean','std']]
summary
# Out:
#             mean       std
# Ticker
# AAPL    0.001045  0.017683
# DIS     0.000455  0.016538
# IBM     0.000174  0.014092
# JPM     0.000578  0.017539
# MSFT    0.000848  0.016253
# SPY     0.000481  0.010865

# %%
summary["mean"]=summary['mean']*252

# %%
summary['std']=summary['std']*np.sqrt(252)
summary
# Out:
#             mean       std
# Ticker
# AAPL    0.263359  0.280713
# DIS     0.114663  0.262525
# IBM     0.043812  0.223710
# JPM     0.145604  0.278422
# MSFT    0.213742  0.258008
# SPY     0.121210  0.172471

# %%
summary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, AAPL to SPY
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   mean    6 non-null      float64
#  1   std     6 non-null      float64
# dtypes: float64(2)
# memory usage: 316.0+ bytes

# %%
summary.plot.scatter(x='std',y='mean', figsize=(12,8))

for i in summary.index:
    plt.annotate(i,xy=(summary.loc[i,"std"]+0.002,summary.loc[i,'mean']+0.002),size =8)
plt.xlabel("Annual risk(std)",fontsize= 12)
plt.ylabel("Annual_return",fontsize= 12)
plt.title('Risk/Return',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Risk/Return')

# %% [markdown]
# Coorelation and Covariance

# %%
ret.cov()
# Out:
# Ticker      AAPL       DIS       IBM       JPM      MSFT       SPY
# Ticker
# AAPL    0.000313  0.000119  0.000099  0.000124  0.000169  0.000132
# DIS     0.000119  0.000273  0.000099  0.000162  0.000124  0.000121
# IBM     0.000099  0.000099  0.000199  0.000128  0.000106  0.000098
# JPM     0.000124  0.000162  0.000128  0.000308  0.000130  0.000142
# MSFT    0.000169  0.000124  0.000106  0.000130  0.000264  0.000133
# SPY     0.000132  0.000121  0.000098  0.000142  0.000133  0.000118

# %%
ret.corr()
# Out:
# Ticker      AAPL       DIS       IBM       JPM      MSFT       SPY
# Ticker
# AAPL    1.000000  0.406629  0.397832  0.398492  0.587868  0.687295
# DIS     0.406629  1.000000  0.426127  0.556923  0.460996  0.676196
# IBM     0.397832  0.426127  1.000000  0.516537  0.462113  0.641400
# JPM     0.398492  0.556923  0.516537  1.000000  0.455525  0.743339
# MSFT    0.587868  0.460996  0.462113  0.455525  1.000000  0.753400
# SPY     0.687295  0.676196  0.641400  0.743339  0.753400  1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(),cmap="Reds",annot=True,annot_kws={"size":15},vmax=0.6)
plt.show()

# %% [markdown]
# #simple return and log returns

# %%
df=pd.DataFrame(index=[2016,2017,2018],data=[100,50,80],columns=["Price"])
df
# Out:
#       Price
# 2016    100
# 2017     50
# 2018     80

# %%
simplereturns=df.pct_change().dropna()
simplereturns
# Out:
#       Price
# 2017   -0.5
# 2018    0.6

# %%
simplereturns.mean()
# Out:
# Price    0.05
# dtype: float64

# %%
100*1.05*1.05
# Out:
# 110.25

# %%
logreturns = np.log(df/df.shift(1)).dropna()
logreturns
# Out:
#          Price
# 2017 -0.693147
# 2018  0.470004

# %%
logreturns.mean()
# Out:
# Price   -0.111572
# dtype: float64

# %%
100*np.exp(logreturns.mean()*2)
# Out:
# Price    80.0
# dtype: float64

# %% [markdown]
# simple moving avg

# %%
SPY = yf.download("SPY")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
SPY
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1993-01-29   43.968750   43.968750   43.750000   43.937500   24.763729
# 1993-02-01   43.968750   44.250000   43.968750   44.250000   24.939871
# 1993-02-02   44.218750   44.375000   44.125000   44.343750   24.992695
# 1993-02-03   44.406250   44.843750   44.375000   44.812500   25.256897
# 1993-02-04   44.968750   45.093750   44.468750   45.000000   25.362583
# ...                ...         ...         ...         ...         ...
# 2024-06-13  543.150024  543.330017  539.590027  542.450012  542.450012
# 2024-06-14  540.880005  542.809998  539.849976  542.780029  542.780029
# 2024-06-17  542.080017  548.530029  541.609985  547.099976  547.099976
# 2024-06-18  547.159973  548.619995  546.729980  548.489990  548.489990
# 2024-06-20  549.440002  550.119995  545.179993  547.000000  547.000000
#
#               Volume
# Date
# 1993-01-29   1003200
# 1993-02-01    480500
# 1993-02-02    201300
# ...

# %%
spy= SPY.Close.to_frame()
spy
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2024-06-13  542.450012
# 2024-06-14  542.780029
# 2024-06-17  547.099976
# 2024-06-18  548.489990
# 2024-06-20  547.000000
#
# [7904 rows x 1 columns]

# %%
spy.plot(figsize=(12,8),fontsize=12)
plt.legend(loc="upper left",fontsize=12)
plt.show()

# %%
spy_roll=spy.rolling(window=10)
spy_roll=spy_roll.mean()
spy_roll
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2024-06-13  534.331995
# 2024-06-14  535.872998
# 2024-06-17  537.802997
# 2024-06-18  539.812994
# 2024-06-20  541.045996
#
# [7904 rows x 1 columns]

# %%
spy_roll2=spy.rolling(window=10)
spy_roll2=spy_roll2.median()
spy_roll2
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2024-06-13  534.664978
# 2024-06-14  535.164978
# 2024-06-17  536.304993
# 2024-06-18  539.154999
# 2024-06-20  541.904999
#
# [7904 rows x 1 columns]

# %%
spy.rolling(window=10,min_periods=5).max().head(15)
# Out:
#                Close
# Date
# 1993-01-29       NaN
# 1993-02-01       NaN
# 1993-02-02       NaN
# 1993-02-03       NaN
# 1993-02-04  45.00000
# 1993-02-05  45.00000
# 1993-02-08  45.00000
# 1993-02-09  45.00000
# 1993-02-10  45.00000
# 1993-02-11  45.00000
# 1993-02-12  45.00000
# 1993-02-16  45.00000
# 1993-02-17  45.00000
# 1993-02-18  45.00000
# 1993-02-19  44.96875

# %%
spy["sma50"]=spy.rolling(window = 50, min_periods=50).mean()
spy
# Out:
#                  Close       sma50
# Date
# 1993-01-29   43.937500         NaN
# 1993-02-01   44.250000         NaN
# 1993-02-02   44.343750         NaN
# 1993-02-03   44.812500         NaN
# 1993-02-04   45.000000         NaN
# ...                ...         ...
# 2024-06-13  542.450012  519.189799
# 2024-06-14  542.780029  519.784000
# 2024-06-17  547.099976  520.357399
# 2024-06-18  548.489990  520.952800
# 2024-06-20  547.000000  521.506400
#
# [7904 rows x 2 columns]

# %%
spy.plot(figsize=(12,8),fontsize=12)
plt.legend(loc="upper left",fontsize=12)
plt.show()

# %%
spy["Sma200"]=spy.Close.rolling(window = 200, min_periods=200).mean()
spy
# Out:
#                  Close       sma50     Sma200
# Date
# 1993-01-29   43.937500         NaN        NaN
# 1993-02-01   44.250000         NaN        NaN
# 1993-02-02   44.343750         NaN        NaN
# 1993-02-03   44.812500         NaN        NaN
# 1993-02-04   45.000000         NaN        NaN
# ...                ...         ...        ...
# 2024-06-13  542.450012  519.189799  480.51050
# 2024-06-14  542.780029  519.784000  480.97860
# 2024-06-17  547.099976  520.357399  481.45905
# 2024-06-18  548.489990  520.952800  481.94975
# 2024-06-20  547.000000  521.506400  482.42880
#
# [7904 rows x 3 columns]

# %%
spy.plot(figsize=(12,8),fontsize=12)
plt.legend(loc="upper left",fontsize=12)
plt.show()

# %%
spy["EMA100"]=spy.Close.ewm(span=100, min_periods=100).mean()
spy
# Out:
#                  Close       sma50     Sma200      EMA100
# Date
# 1993-01-29   43.937500         NaN        NaN         NaN
# 1993-02-01   44.250000         NaN        NaN         NaN
# 1993-02-02   44.343750         NaN        NaN         NaN
# 1993-02-03   44.812500         NaN        NaN         NaN
# 1993-02-04   45.000000         NaN        NaN         NaN
# ...                ...         ...        ...         ...
# 2024-06-13  542.450012  519.189799  480.51050  509.805746
# 2024-06-14  542.780029  519.784000  480.97860  510.458702
# 2024-06-17  547.099976  520.357399  481.45905  511.184272
# 2024-06-18  548.489990  520.952800  481.94975  511.922999
# 2024-06-20  547.000000  521.506400  482.42880  512.617593
#
# [7904 rows x 4 columns]

# %%
spy.plot(figsize=(12,8),fontsize=12)
plt.legend(loc="upper left",fontsize=12)
plt.show()

# %%
spy["Day"]=spy.index.day_name()
spy
# Out:
#                  Close       sma50     Sma200      EMA100        Day
# Date
# 1993-01-29   43.937500         NaN        NaN         NaN     Friday
# 1993-02-01   44.250000         NaN        NaN         NaN     Monday
# 1993-02-02   44.343750         NaN        NaN         NaN    Tuesday
# 1993-02-03   44.812500         NaN        NaN         NaN  Wednesday
# 1993-02-04   45.000000         NaN        NaN         NaN   Thursday
# ...                ...         ...        ...         ...        ...
# 2024-06-13  542.450012  519.189799  480.51050  509.805746   Thursday
# 2024-06-14  542.780029  519.784000  480.97860  510.458702     Friday
# 2024-06-17  547.099976  520.357399  481.45905  511.184272     Monday
# 2024-06-18  548.489990  520.952800  481.94975  511.922999    Tuesday
# 2024-06-20  547.000000  521.506400  482.42880  512.617593   Thursday
#
# [7904 rows x 5 columns]

# %%
spy['Quarter']=spy.index.quarter
spy
# Out:
#                  Close       sma50     Sma200      EMA100        Day  Quarter
# Date
# 1993-01-29   43.937500         NaN        NaN         NaN     Friday        1
# 1993-02-01   44.250000         NaN        NaN         NaN     Monday        1
# 1993-02-02   44.343750         NaN        NaN         NaN    Tuesday        1
# 1993-02-03   44.812500         NaN        NaN         NaN  Wednesday        1
# 1993-02-04   45.000000         NaN        NaN         NaN   Thursday        1
# ...                ...         ...        ...         ...        ...      ...
# 2024-06-13  542.450012  519.189799  480.51050  509.805746   Thursday        2
# 2024-06-14  542.780029  519.784000  480.97860  510.458702     Friday        2
# 2024-06-17  547.099976  520.357399  481.45905  511.184272     Monday        2
# 2024-06-18  548.489990  520.952800  481.94975  511.922999    Tuesday        2
# 2024-06-20  547.000000  521.506400  482.42880  512.617593   Thursday        2
#
# [7904 rows x 6 columns]

# %%
a =spy.Close.to_frame()

# %%
a
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2024-06-13  542.450012
# 2024-06-14  542.780029
# 2024-06-17  547.099976
# 2024-06-18  548.489990
# 2024-06-20  547.000000
#
# [7904 rows x 1 columns]

# %%
all_days = pd.date_range(start ='2010-12-31' , end = '2024-05-01' , freq = "D")
all_days
# Out:
# DatetimeIndex(['2010-12-31', '2011-01-01', '2011-01-02', '2011-01-03',
#                '2011-01-04', '2011-01-05', '2011-01-06', '2011-01-07',
#                '2011-01-08', '2011-01-09',
#                ...
#                '2024-04-22', '2024-04-23', '2024-04-24', '2024-04-25',
#                '2024-04-26', '2024-04-27', '2024-04-28', '2024-04-29',
#                '2024-04-30', '2024-05-01'],
#               dtype='datetime64[ns]', length=4871, freq='D')

# %%
a=a.reindex(all_days)
a
# Out:
#                  Close
# 2010-12-31  125.750000
# 2011-01-01         NaN
# 2011-01-02         NaN
# 2011-01-03  127.050003
# 2011-01-04  126.980003
# ...                ...
# 2024-04-27         NaN
# 2024-04-28         NaN
# 2024-04-29  510.059998
# 2024-04-30  501.980011
# 2024-05-01  500.350006
#
# [4871 rows x 1 columns]

# %%
a.fillna(method='ffill')
# Out:
# C:\Users\nayan\AppData\Local\Temp\ipykernel_4296\218834790.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   a.fillna(method='ffill')
#                  Close
# 2010-12-31  125.750000
# 2011-01-01  125.750000
# 2011-01-02  125.750000
# 2011-01-03  127.050003
# 2011-01-04  126.980003
# ...                ...
# 2024-04-27  508.260010
# 2024-04-28  508.260010
# 2024-04-29  510.059998
# 2024-04-30  501.980011
# 2024-05-01  500.350006
#
# [4871 rows x 1 columns]

# %%
a.fillna(method='bfill')
# Out:
# C:\Users\nayan\AppData\Local\Temp\ipykernel_4296\2519132369.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   a.fillna(method='bfill')
#                  Close
# 2010-12-31  125.750000
# 2011-01-01  127.050003
# 2011-01-02  127.050003
# 2011-01-03  127.050003
# 2011-01-04  126.980003
# ...                ...
# 2024-04-27  510.059998
# 2024-04-28  510.059998
# 2024-04-29  510.059998
# 2024-04-30  501.980011
# 2024-05-01  500.350006
#
# [4871 rows x 1 columns]

# %%
spy2=yf.download("SPY",interval="1wk")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
spy2
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1993-01-25   43.968750   43.968750   43.750000   43.937500   24.763739
# 1993-02-01   43.968750   45.093750   43.968750   44.968750   25.344950
# 1993-02-08   44.968750   45.125000   44.531250   44.593750   25.133604
# 1993-02-15   44.468750   44.468750   42.812500   43.562500   24.552376
# 1993-02-22   43.687500   44.437500   43.468750   44.406250   25.027918
# ...                ...         ...         ...         ...         ...
# 2024-05-20  529.570007  533.070007  524.719971  529.440002  529.440002
# 2024-05-27  530.270020  530.510010  518.359985  527.369995  527.369995
# 2024-06-03  529.020020  536.890015  522.599976  534.010010  534.010010
# 2024-06-10  533.179993  544.119995  532.049988  542.780029  542.780029
# 2024-06-17  542.080017  550.119995  541.609985  547.000000  547.000000
#
#                Volume
# Date
# 1993-01-25    1003200
# 1993-02-01    2234800
# 1993-02-08    1159800
# ...

# %% [markdown]
# CUMULATIVE DATA

# %%
apple=yf.download("AAPL")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
apple=apple.Close.to_frame()
apple
# Out:
#                  Close
# Date
# 1980-12-12    0.128348
# 1980-12-15    0.121652
# 1980-12-16    0.112723
# 1980-12-17    0.115513
# 1980-12-18    0.118862
# ...                ...
# 2024-06-13  214.240005
# 2024-06-14  212.490005
# 2024-06-17  216.669998
# 2024-06-18  214.289993
# 2024-06-20  209.679993
#
# [10971 rows x 1 columns]

# %%
apple["d_returns"]=np.log(apple.div(apple.shift(1)))
apple
# Out:
#                  Close  d_returns
# Date
# 1980-12-12    0.128348        NaN
# 1980-12-15    0.121652  -0.053581
# 1980-12-16    0.112723  -0.076231
# 1980-12-17    0.115513   0.024450
# 1980-12-18    0.118862   0.028580
# ...                ...        ...
# 2024-06-13  214.240005   0.005476
# 2024-06-14  212.490005  -0.008202
# 2024-06-17  216.669998   0.019480
# 2024-06-18  214.289993  -0.011045
# 2024-06-20  209.679993  -0.021748
#
# [10971 rows x 2 columns]

# %%
apple.dropna(inplace=True)
apple
# Out:
#                  Close  d_returns
# Date
# 1980-12-15    0.121652  -0.053581
# 1980-12-16    0.112723  -0.076231
# 1980-12-17    0.115513   0.024450
# 1980-12-18    0.118862   0.028580
# 1980-12-19    0.126116   0.059239
# ...                ...        ...
# 2024-06-13  214.240005   0.005476
# 2024-06-14  212.490005  -0.008202
# 2024-06-17  216.669998   0.019480
# 2024-06-18  214.289993  -0.011045
# 2024-06-20  209.679993  -0.021748
#
# [10970 rows x 2 columns]

# %%
apple.d_returns.sum()
# Out:
# 7.398592533604456

# %%
np.exp(apple.d_returns.sum())
# Out:
# 1633.6834565383276

# %%
apple['cummreturns']=apple.d_returns.cumsum().apply(np.exp)
apple
# Out:
#                  Close  d_returns  cummreturns
# Date
# 1980-12-15    0.121652  -0.053581     0.947829
# 1980-12-16    0.112723  -0.076231     0.878261
# 1980-12-17    0.115513   0.024450     0.899998
# 1980-12-18    0.118862   0.028580     0.926092
# 1980-12-19    0.126116   0.059239     0.982610
# ...                ...        ...          ...
# 2024-06-13  214.240005   0.005476  1669.211966
# 2024-06-14  212.490005  -0.008202  1655.577159
# 2024-06-17  216.669998   0.019480  1688.144811
# 2024-06-18  214.289993  -0.011045  1669.601436
# 2024-06-20  209.679993  -0.021748  1633.683457
#
# [10970 rows x 3 columns]

# %%
apple['cummreturns'].plot(figsize=(12,8),title="Apple buy and hold",fontsize=12)
plt.show()

# %%
apple.d_returns.mean() *252
# Out:
# 0.16995855227605497

# %%
apple.d_returns.std() *np.sqrt(252)
# Out:
# 0.4498586182771645

# %% [markdown]
# #how to calculate drawdown

# %%
apple['cummax']=apple.cummreturns.cummax()
apple
# Out:
#                  Close  d_returns  cummreturns       cummax
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829
# 1980-12-17    0.115513   0.024450     0.899998     0.947829
# 1980-12-18    0.118862   0.028580     0.926092     0.947829
# 1980-12-19    0.126116   0.059239     0.982610     0.982610
# ...                ...        ...          ...          ...
# 2024-06-13  214.240005   0.005476  1669.211966  1669.211966
# 2024-06-14  212.490005  -0.008202  1655.577159  1669.211966
# 2024-06-17  216.669998   0.019480  1688.144811  1688.144811
# 2024-06-18  214.289993  -0.011045  1669.601436  1688.144811
# 2024-06-20  209.679993  -0.021748  1633.683457  1688.144811
#
# [10970 rows x 4 columns]

# %%
apple[['cummreturns','cummax']].plot(figsize=(12,8),title="Apple buy and hold+cummax",fontsize=12)
plt.show()

# %%
apple['drawdown']=apple['cummax']-apple['cummreturns']
apple
# Out:
#                  Close  d_returns  cummreturns       cummax   drawdown
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829   0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829   0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829   0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829   0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610   0.000000
# ...                ...        ...          ...          ...        ...
# 2024-06-13  214.240005   0.005476  1669.211966  1669.211966   0.000000
# 2024-06-14  212.490005  -0.008202  1655.577159  1669.211966  13.634806
# 2024-06-17  216.669998   0.019480  1688.144811  1688.144811   0.000000
# 2024-06-18  214.289993  -0.011045  1669.601436  1688.144811  18.543374
# 2024-06-20  209.679993  -0.021748  1633.683457  1688.144811  54.461354
#
# [10970 rows x 5 columns]

# %%
apple.drawdown.max()
# Out:
# 444.02718404402026

# %%
apple.drawdown.idxmax()
# Out:
# Timestamp('2023-01-05 00:00:00')

# %%
apple.loc[(apple.index <= '2024-05-31')]
# Out:
#                  Close  d_returns  cummreturns       cummax   drawdown
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829   0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829   0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829   0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829   0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610   0.000000
# ...                ...        ...          ...          ...        ...
# 2024-05-24  189.979996   0.016452  1480.194520  1543.537972  63.343452
# 2024-05-28  189.990005   0.000053  1480.272509  1543.537972  63.265462
# 2024-05-29  190.289993   0.001578  1482.609809  1543.537972  60.928162
# 2024-05-30  191.289993   0.005241  1490.401127  1543.537972  53.136844
# 2024-05-31  192.250000   0.005006  1497.880845  1543.537972  45.657127
#
# [10957 rows x 5 columns]

# %%
apple['drawdownmaxper']=(apple['cummax']-apple['cummreturns'])/apple['cummax']
apple
# Out:
#                  Close  d_returns  cummreturns       cummax   drawdown  \
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829   0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829   0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829   0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829   0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610   0.000000
# ...                ...        ...          ...          ...        ...
# 2024-06-13  214.240005   0.005476  1669.211966  1669.211966   0.000000
# 2024-06-14  212.490005  -0.008202  1655.577159  1669.211966  13.634806
# 2024-06-17  216.669998   0.019480  1688.144811  1688.144811   0.000000
# 2024-06-18  214.289993  -0.011045  1669.601436  1688.144811  18.543374
# 2024-06-20  209.679993  -0.021748  1633.683457  1688.144811  54.461354
#
#             drawdownmaxper
# Date
# 1980-12-15        0.000000
# 1980-12-16        0.073398
# ...

# %%
apple.drawdownmaxper.max()
# Out:
# 0.82216567924191

# %%
apple.drawdownmaxper.idxmax()
# Out:
# Timestamp('1997-12-23 00:00:00')

# %%
apple.loc[(apple.index<='1997-12-23')]
# Out:
#                Close  d_returns  cummreturns    cummax  drawdown  \
# Date
# 1980-12-15  0.121652  -0.053581     0.947829  0.947829  0.000000
# 1980-12-16  0.112723  -0.076231     0.878261  0.947829  0.069569
# 1980-12-17  0.115513   0.024450     0.899998  0.947829  0.047831
# 1980-12-18  0.118862   0.028580     0.926092  0.947829  0.021738
# 1980-12-19  0.126116   0.059239     0.982610  0.982610  0.000000
# ...              ...        ...          ...       ...       ...
# 1997-12-17  0.124442  -0.026549     0.969567  5.060882  4.091315
# 1997-12-18  0.123326  -0.009008     0.960872  5.060882  4.100010
# 1997-12-19  0.122210  -0.009090     0.952177  5.060882  4.108705
# 1997-12-22  0.118862  -0.027778     0.926092  5.060882  4.134790
# 1997-12-23  0.115513  -0.028580     0.899998  5.060882  4.160883
#
#             drawdownmaxper
# Date
# 1980-12-15        0.000000
# 1980-12-16        0.073398
# 1980-12-17        0.050464
# 1980-12-18        0.022934
# 1980-12-19        0.000000
# ...

# %% [markdown]
# sma startegy

# %%
data =apple.Close.iloc[(apple.index>='1991-01-01')]
data=data.to_frame()

# %% [markdown]
# data

# %%
sma_s=50
sma_l=100

# %%
data['sma_s']=data.Close.rolling(sma_s).mean(50)
data['sma_l']=data.Close.rolling(sma_l).mean(50)

# %%
data
# Out:
#                  Close       sma_s     sma_l
# Date
# 1991-01-02    0.388393         NaN       NaN
# 1991-01-03    0.383929         NaN       NaN
# 1991-01-04    0.386161         NaN       NaN
# 1991-01-07    0.386161         NaN       NaN
# 1991-01-08    0.386161         NaN       NaN
# ...                ...         ...       ...
# 2024-06-13  214.240005  182.485400  181.2267
# 2024-06-14  212.490005  183.358800  181.3998
# 2024-06-17  216.669998  184.300600  181.6215
# 2024-06-18  214.289993  185.217400  181.8227
# 2024-06-20  209.679993  186.017599  181.9953
#
# [8430 rows x 3 columns]

# %%
data.plot(figsize=(12,8),title='AAPLE-SMA{} | SMA{}'.format(sma_s,sma_l),fontsize=12)
# Out:
# <Axes: title={'center': 'AAPLE-SMA50 | SMA100'}, xlabel='Date'>

# %%
data.loc['2020'].plot(figsize=(12,8),title='AAPLE-SMA{} | SMA{}'.format(sma_s,sma_l),fontsize=12)
# Out:
# <Axes: title={'center': 'AAPLE-SMA50 | SMA100'}, xlabel='Date'>

# %%
data.dropna(inplace=True)

data
# Out:
#                  Close       sma_s       sma_l
# Date
# 1991-05-23    0.402902    0.534420    0.513326
# 1991-05-24    0.409598    0.530960    0.513538
# 1991-05-28    0.410714    0.527344    0.513806
# 1991-05-29    0.419643    0.523638    0.514141
# 1991-05-30    0.425223    0.519732    0.514531
# ...                ...         ...         ...
# 2024-06-13  214.240005  182.485400  181.226700
# 2024-06-14  212.490005  183.358800  181.399800
# 2024-06-17  216.669998  184.300600  181.621500
# 2024-06-18  214.289993  185.217400  181.822700
# 2024-06-20  209.679993  186.017599  181.995300
#
# [8331 rows x 3 columns]

# %%
data["position"]=np.where(data['sma_s']>data['sma_l'],1,-1)

# %%
data
# Out:
#                  Close       sma_s       sma_l  position
# Date
# 1991-05-23    0.402902    0.534420    0.513326         1
# 1991-05-24    0.409598    0.530960    0.513538         1
# 1991-05-28    0.410714    0.527344    0.513806         1
# 1991-05-29    0.419643    0.523638    0.514141         1
# 1991-05-30    0.425223    0.519732    0.514531         1
# ...                ...         ...         ...       ...
# 2024-06-13  214.240005  182.485400  181.226700         1
# 2024-06-14  212.490005  183.358800  181.399800         1
# 2024-06-17  216.669998  184.300600  181.621500         1
# 2024-06-18  214.289993  185.217400  181.822700         1
# 2024-06-20  209.679993  186.017599  181.995300         1
#
# [8331 rows x 4 columns]

# %%
data.loc['2022':,['sma_s','sma_l','position']].plot(figsize=(12,8),title='AAPLE-SMA{} | SMA{}'.format(sma_s,sma_l),fontsize=12,secondary_y='position')
# Out:
# <Axes: title={'center': 'AAPLE-SMA50 | SMA100'}, xlabel='Date'>

# %%
data['returnsb&h']=np.log(data.Close.div(data.Close.shift(1)))

# %%
data['strategy']=data['returnsb&h']*data.position.shift(1)
data.dropna(inplace=True)

# %%
data
# Out:
#                  Close       sma_s       sma_l  position  returnsb&h  strategy
# Date
# 1991-05-28    0.410714    0.527344    0.513806         1    0.002721  0.002721
# 1991-05-29    0.419643    0.523638    0.514141         1    0.021507  0.021507
# 1991-05-30    0.425223    0.519732    0.514531         1    0.013209  0.013209
# 1991-05-31    0.419643    0.516027    0.514866         1   -0.013209 -0.013209
# 1991-06-03    0.439732    0.513259    0.515223        -1    0.046761  0.046761
# ...                ...         ...         ...       ...         ...       ...
# 2024-06-13  214.240005  182.485400  181.226700         1    0.005476  0.005476
# 2024-06-14  212.490005  183.358800  181.399800         1   -0.008202 -0.008202
# 2024-06-17  216.669998  184.300600  181.621500         1    0.019480  0.019480
# 2024-06-18  214.289993  185.217400  181.822700         1   -0.011045 -0.011045
# 2024-06-20  209.679993  186.017599  181.995300         1   -0.021748 -0.021748
#
# ...

# %%
data[['returnsb&h','strategy']].sum()
# Out:
# returnsb&h    6.238162
# strategy      1.585781
# dtype: float64

# %%
data[['returnsb&h','strategy']].sum().apply(np.exp) #what $1 will be
# Out:
# returnsb&h    511.916553
# strategy        4.883102
# dtype: float64

# %%
data[['returnsb&h','strategy']].std()*np.sqrt(252) #annual stddev
# Out:
# returnsb&h    0.432850
# strategy      0.433002
# dtype: float64

# %%
data.Close.plot(figsize=(12,8)) #general bias towards long
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# startegy adjusted to long bias

# %%
data['position2']=np.where(data['sma_s']>data['sma_l'],1,0)

# %%
data
# Out:
#                  Close       sma_s       sma_l  position  returnsb&h  \
# Date
# 1991-05-28    0.410714    0.527344    0.513806         1    0.002721
# 1991-05-29    0.419643    0.523638    0.514141         1    0.021507
# 1991-05-30    0.425223    0.519732    0.514531         1    0.013209
# 1991-05-31    0.419643    0.516027    0.514866         1   -0.013209
# 1991-06-03    0.439732    0.513259    0.515223        -1    0.046761
# ...                ...         ...         ...       ...         ...
# 2024-06-13  214.240005  182.485400  181.226700         1    0.005476
# 2024-06-14  212.490005  183.358800  181.399800         1   -0.008202
# 2024-06-17  216.669998  184.300600  181.621500         1    0.019480
# 2024-06-18  214.289993  185.217400  181.822700         1   -0.011045
# 2024-06-20  209.679993  186.017599  181.995300         1   -0.021748
#
#             strategy  position2
# Date
# 1991-05-28  0.002721          1
# 1991-05-29  0.021507          1
# ...

# %%
data['strategy2']=data['returnsb&h']*data.position2.shift(1)

# %%
data.dropna()
# Out:
#                  Close       sma_s       sma_l  position  returnsb&h  \
# Date
# 1991-05-29    0.419643    0.523638    0.514141         1    0.021507
# 1991-05-30    0.425223    0.519732    0.514531         1    0.013209
# 1991-05-31    0.419643    0.516027    0.514866         1   -0.013209
# 1991-06-03    0.439732    0.513259    0.515223        -1    0.046761
# 1991-06-04    0.438616    0.510737    0.515402        -1   -0.002541
# ...                ...         ...         ...       ...         ...
# 2024-06-13  214.240005  182.485400  181.226700         1    0.005476
# 2024-06-14  212.490005  183.358800  181.399800         1   -0.008202
# 2024-06-17  216.669998  184.300600  181.621500         1    0.019480
# 2024-06-18  214.289993  185.217400  181.822700         1   -0.011045
# 2024-06-20  209.679993  186.017599  181.995300         1   -0.021748
#
#             strategy  position2  strategy2
# Date
# 1991-05-29  0.021507          1   0.021507
# ...

# %%
a=data[['returnsb&h','strategy2']].sum()

# %%
b=data[['returnsb&h','strategy2']].std()*np.sqrt(252)

# %%
#strategy 2 is better than strategy1

# %%
# creating our first function

# %%
def test_strategy(stock,start,end,SMA):
    df=yf.download(stock,start=start,end=end)
    data=df.Close.to_frame()
    data['returns']=np.log(data.Close.div(data.Close.shift(1)))
    data['SMA_S']=data.Close.rolling(int(SMA[0])).mean()
    data['SMA_L']=data.Close.rolling(int(SMA[1])).mean()
    data.dropna(inplace=True)

    data['position']=np.where(data['SMA_S']>data['SMA_L'],1,-1)

    data['strategy3']=data['returns']*data['position'].shift(1)
    data.dropna(inplace=True)
    ret=np.exp(data['strategy3'].sum())
    std=data['strategy3'].std() *np.sqrt(252)

    return ret,std

# %%
test_strategy('SPY','2000-01-01','2024-05-31',(50,100))
# Out:
# [*********************100%%**********************]  1 of 1 completed
# (2.0103113722924317, 0.19398216082866043)

# %% [markdown]
# Creating our first class

# %%
class SMABacktester():
    def __init__(self,symbol,SMA_S, SMA_L,start,end):
        self.symbol=symbol
        self.SMA_S=SMA_S
        self.SMA_L=SMA_L
        self.start=start
        self.end=end
        self.results=None
        self.get_data()
        
    def get_data(self):
        df=yf.download(self.symbol,start=self.start,end=self.end)
        data=df.Close.to_frame()
        data["returns"]=np.log(data.Close.div(data.Close.shift(1)))
        data["SMA_S"]=data.Close.rolling(self.SMA_S).mean()
        data["SMA_L"]=data.Close.rolling(self.SMA_L).mean()
        data.dropna(inplace=True)
        self.data2=data
        
        return data
    
    def test_results(self):
        data=self.data2.copy().dropna()
        data["position"]=np.where(data["SMA_S"]>data["SMA_L"],1,-1)
        data["strategy"]=data["returns"]*data.position.shift(1)
        data.dropna(inplace=True)
        data["returnsbh"]=data["returns"].cumsum().apply(np.exp)
        data["returnsstrategy"]=data["strategy"].cumsum().apply(np.exp)
        perf=data["returnsstrategy"].iloc[-1]
        outperf=perf-data["returnsbh"].iloc[-1]
        self.results=data
        
        ret=np.exp(data["strategy"].sum())
        std= data["strategy"].std()*np.sqrt(252)
    
        #return ret,std
        return round(perf,6), round(outperf,6)
    
    def plot_results(self):
        if self.results is None:
            print("Run the test please")
        else:
            title="{}| SMA_S={} | SMA_L{}".format(self.symbol,self.SMA_S, self.SMA_L)
            self.results[["returnsbh","returnsstrategy"]].plot(title=title, figsize=(12,8))

# %%
tester = SMABacktester('INFY',50,100,'2020-01-01','2024-01-01')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
tester.test_results()
# Out:
# (3.016129, 0.989668)

# %%
tester.plot_results()
